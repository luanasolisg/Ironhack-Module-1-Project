# %% [markdown]
# # Adquisition

# %%
import pandas as pd
import sqlite3
from functools import reduce

# %%
#Import Data Base
# Create the connection with my downloaded data base
cnx = sqlite3.connect('/home/luana/IRONHACK/Ironhack-Module-1-Project/data/luanasolis.db')
# create the dataframe from a query
df_business = pd.read_sql_query("SELECT * FROM business_info", cnx)
df_rank = pd.read_sql_query("SELECT * FROM rank_info", cnx)
df_personal = pd.read_sql_query("SELECT * FROM personal_info", cnx)

# %%
#function for merging queris:
dfs = [df_business,df_rank,df_personal]
def merge_df (list_df , column):
    return reduce(lambda left,right: pd.merge(left,right,on=column), list_df)

# %%
#given data base
df_ppl1 = merge_df (dfs , 'id')
df_ppl1.head()
# Out:
#      id  Unnamed: 0_x                                           Source  \
# 0  7706            52                           Technology  ==> Amazon
# 1  7338            53                        Technology  ==> Microsoft
# 2  9531            54  Finance and Investments  ==> Berkshire Hathaway
# 3  5476            55                       Fashion & Retail  ==> LVMH
# 4  9878            56                         Technology  ==> Facebook
#
#         worth          worthChange realTimeWorth  realTimePosition  \
# 0  112.0 BUSD     0.0 millions USD          None                 1
# 1   90.0 BUSD  -0.001 millions USD          None                 2
# 2   84.0 BUSD  -0.002 millions USD          None                 3
# 3   72.0 BUSD     0.0 millions USD          None                 4
# 4   71.0 BUSD     0.0 millions USD          None                 5
#
#               name  position  Unnamed: 0_y    lastName           age  \
# 0       jeff BEZos       1.0            52       BEZOS  54 years old
# 1       bill GATES       2.0            53       gATEs  62 years old
# 2   wARREN BUFFETt       3.0            54     buFFETt  87 years old
# 3  bERNARD ARNAULT       4.0            55     ARNAULT  69 years old
# 4  mark ZUCKerberg       5.0            56  zuckeRBERG          1985
#
#    Unnamed: 0 gender        country  \
# 0          52      M  United States
# 1          53      M  United States
# 2          54      M           None
# 3          55   None           None
# 4          56      M           None
#
#                                                image
# 0  https://specials-images.forbesimg.com/imageser...
# 1  https://specials-images.forbesimg.com/imageser...
# 2  https://specials-images.forbesimg.com/imageser...
# 3  https://specials-images.forbesimg.com/imageser...
# 4  https://specials-images.forbesimg.com/imageser...
